# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv("Day 4_Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
## getting the dependent and independent features

X = df.iloc[:, 3:13]
y = df.iloc[:, 13]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
geography = pd.get_dummies(X["Geography"], drop_first=True).astype(int)

# %%
geography.head()
# Out:
#    Germany  Spain
# 0        0      0
# 1        0      1
# 2        0      0
# 3        0      0
# 4        0      1

# %%
gender = pd.get_dummies(X["Gender"], drop_first=True).astype(int)
gender.head()
# Out:
#    Male
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
X = X.drop(["Geography","Gender"], axis=1)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
X = pd.concat([X,geography,gender], axis = 1)
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
## Hyperparameter optimization

params = {
    "learning_rate":[0.05,0.10,0.15,0.20,0.25,0.30],
    "max_depth":[3,4,5,6,8,10,12,15],
    "min_child_weight":[1,3,5,7],
    "gamma":[0.0,0.1,0.2,0.3,0.4],
    'n_estimators': [50, 100, 150],
    "colsample_bytree": [0.3,0.4,0.5,0.7]
}

# %%
import sklearn

# %%
#pip install xgboost

# %%
import xgboost

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
classifier = xgboost.XGBClassifier(booster="gbtree")

# %%
random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=4, min_child_weight=7, n_estimators=50;, score=0.873 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=4, min_child_weight=7, n_estimators=50;, score=0.866 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=4, min_child_weight=7, n_estimators=50;, score=0.861 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=4, min_child_weight=7, n_estimators=50;, score=0.865 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.3, max_depth=4, min_child_weight=7, n_estimators=50;, score=0.867 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=7, n_estimators=150;, score=0.864 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=7, n_estimators=150;, score=0.856 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=7, n_estimators=150;, score=0.856 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=7, n_estimators=150;, score=0.861 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=150;, score=0.859 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=150;, score=0.864 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=150;, score=0.857 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=7, n_estimators=150;, score=0.850 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=50;, score=0.853 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=150;, score=0.859 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=150;, score=0.858 total time=   0.4s
# [CV 2/5] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=50;, score=0.860 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=50;, score=0.854 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=150;, score=0.865 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=150;, score=0.860 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=50;, score=0.855 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.1, max_depth=12, min_child_weight=7, n_estimators=50;, score=0.854 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=150;, score=0.861 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=150;, score=0.862 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.3, gamma=0.0, learning_rate=0.2, max_depth=4, min_child_weight=7, n_estimators=150;, score=0.862 total time=   0.2s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster='gbtree',
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_const...
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None, ...),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.3, 0.4, 0.5,
#                                                              0.7],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2,
#                                                           0.25, 0.3],
#                                         'max_depth': [3, 4, 5, 6, 8, 10, 12,
#                                                       15],
#                                         'min_child_weight': [1, 3, 5, 7],
#                                         'n_estimators': [50, 100, 150]},
#                    scoring='roc_auc', verbose=3)

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.4, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=0.2, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=7, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=50,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
random_search.best_params_

# params = {
#     "learning_rate":[0.05,0.10,0.15,0.20,0.25,0.30],
#     "max_depth":[3,4,5,6,8,10,12,15],
#     "min_child_weight":[1,3,5,7],
#     "gamma":[0.0,0.1,0.2,0.3,0.4],
#     "colsample_bytree": [0.3,0.4,0.5,0.7]
# }
# Out:
# {'n_estimators': 50,
#  'min_child_weight': 7,
#  'max_depth': 4,
#  'learning_rate': 0.3,
#  'gamma': 0.2,
#  'colsample_bytree': 0.4}

# %%
import numpy as np

# %%
classifier=xgboost.XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
              colsample_bylevel=None, colsample_bynode=None,
              colsample_bytree=0.4, device=None, early_stopping_rounds=None,
              enable_categorical=False, eval_metric=None, feature_types=None,
              feature_weights=None, gamma=0.2, grow_policy=None,
              importance_type=None, interaction_constraints=None,
              learning_rate=0.3, max_bin=None, max_cat_threshold=None,
              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
              max_leaves=None, min_child_weight=7,
              monotone_constraints=None, multi_strategy=None, n_estimators=50,
              n_jobs=None, num_parallel_tree=None)

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(classifier,X,y,cv=10)

# %%
score
# Out:
# array([0.876, 0.868, 0.874, 0.87 , 0.865, 0.85 , 0.858, 0.878, 0.859,
#        0.852])

# %%
score.mean()
# Out:
# np.float64(0.865)
